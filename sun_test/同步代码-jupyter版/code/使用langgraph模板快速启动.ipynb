# %% [markdown]
# ## 使用langgraph模板快速启动
# ****

# %%
! pip install "langgraph-cli[inmem]" --upgrade

# %% [markdown]
# 成熟模板
# ****
#  - 新 LangGraph 项目 (一个简单、最小且具有记忆功能的聊天机器人。)
#  - ReAct Agent
#  - Memory Agent
#  - Retrieval Agent
#  - Data-Enrichment Agent

# %%
! langgraph new --help
# Out:
# Usage: langgraph new [OPTIONS] [PATH]
#
#   🌱 Create a new LangGraph project from a template.
#
# Options:
#   --template TEXT  The name of the template to use. Available options: new-
#                    langgraph-project-python new-langgraph-project-js react-
#                    agent-python react-agent-js memory-agent-python memory-
#                    agent-js retrieval-agent-python retrieval-agent-js data-
#                    enrichment-agent-python data-enrichment-agent-js
#   --help           Show this message and exit.

# %%
! langgraph new 目录名 --template memory-agent-python

# %%
! langgraph new MemoryAgent --template memory-agent-python
# Out:
# 📥 Attempting to download repository as a ZIP archive...
# URL: https://github.com/langchain-ai/memory-agent/archive/refs/heads/main.zip
# ✅ Downloaded and extracted repository to /Volumes/MOVESPEED/AI课程/localCode/code/MemoryAgent
# 🎉 New project created at /Volumes/MOVESPEED/AI课程/localCode/code/MemoryAgent

# %%
! cd MemoryAgent && cp .env.example .env

# %%
! cd MemoryAgent && python -m pip install -e .
# Out:
# Obtaining file:///Volumes/MOVESPEED/AI%E8%AF%BE%E7%A8%8B/localCode/code/MemoryAgent
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for memory-agent (pyproject.toml) ... done
#   Created wheel for memory-agent: filename=memory_agent-0.0.1-0.editable-py3-none-any.whl size=6823 sha256=3191b2b8aedd11a78a1948b6365e93a87792bf343984e3d238024650b6201dec
#   Stored in directory: /private/var/folders/gp/1nc10nrd3kjfxp5kkm9h93l80000gn/T/pip-ephem-wheel-cache-k_0pzuzs/wheels/5c/b0/6f/7dc3f477bf66323e5288818bb995066cd6da9cd54839b268a2
# Successfully built memory-agent
# ...
#   Attempting uninstall: langgraph
#     Found existing installation: langgraph 0.3.22
#     Uninstalling langgraph-0.3.22:
#       Successfully uninstalled langgraph-0.3.22
# ...

# %% [markdown]
# 启动

# %%
! cd MemoryAgent && langgraph dev --allow-blocking
# Out:
# INFO:langgraph_api.cli:
#
#         Welcome to
#
# ╦  ┌─┐┌┐┌┌─┐╔═╗┬─┐┌─┐┌─┐┬ ┬
# ║  ├─┤││││ ┬║ ╦├┬┘├─┤├─┘├─┤
# ╩═╝┴ ┴┘└┘└─┘╚═╝┴└─┴ ┴┴  ┴ ┴
#
# - 🚀 API: http://127.0.0.1:2024
# - 🎨 Studio UI: https://smith.langchain.com/studio/?baseUrl=http://127.0.0.1:2024
# - 📚 API Docs: http://127.0.0.1:2024/docs
#
# This in-memory server is designed for development and testing.
# For production use, please use LangGraph Cloud.
#
#
# 2025-04-03T08:02:40.067477Z [info     ] Will watch for changes in these directories: ['/Volumes/MOVESPEED/AI课程/localCode/code/MemoryAgent'] [uvicorn.error] api_variant=local_dev thread_name=MainThread
# 2025-04-03T08:02:40.067768Z [info     ] Uvicorn running on http://127.0.0.1:2024 (Press CTRL+C to quit) [uvicorn.error] api_variant=local_dev color_message='Uvicorn running on \x1b%s://%s:%d\x1b (Press CTRL+C to quit)' thread_name=MainThread
# ...
